# %% [markdown]
# DATA SCIENCE

# %%
lista = ["banan", "chleb"]

# %%
#SŁOWNIK - dictionary (dict)

# %%
student = {"Name" : "Patryk Hubar", "Age": 31, "Email" : "aaa@aaa.com"}

# %%
type(student)
# Out:
# dict

# %%
student["Age"]
# Out:
# 31

# %%
student["Grade"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-0ed638ce3221> in <cell line: 1>()
# ----> 1 student["Grade"]
#
# KeyError: 'Grade'

# %%
student.get("Grade", "No data")
# Out:
# 'No data'

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'Email'])

# %%
student.values()
# Out:
# dict_values(['Patryk Hubar', 31, 'aaa@aaa.com'])

# %%
student.items()
# Out:
# dict_items([('Name', 'Patryk Hubar'), ('Age', 31), ('Email', 'aaa@aaa.com')])

# %%
student.update({"Grade":5})

# %%
student
# Out:
# {'Name': 'Patryk Hubar', 'Age': 31, 'Email': 'aaa@aaa.com', 'Grade': 5}

# %%
student.pop("Grade")
# Out:
# 5

# %%
student
# Out:
# {'Name': 'Patryk Hubar', 'Age': 31, 'Email': 'aaa@aaa.com'}

# %%
student.clear()

# %%
for elem in student:
  print(elem)
# Out:
# Name
# Age
# Email

# %%
for key in student.keys():
  print(key)
# Out:
# Name
# Age
# Email

# %%
for value in student.values():
  print(value)
# Out:
# Patryk Hubar
# 31
# aaa@aaa.com

# %%
for k, v in student.items():
  print(k)
  print(v)
# Out:
# Name
# Patryk Hubar
# Age
# 31
# Email
# aaa@aaa.com

# %%
student
# Out:
# {'Name': 'Patryk Hubar', 'Age': 31, 'Email': 'aaa@aaa.com'}

# %%
student2 = {"Name": "Ala Kot", "Age": 21, "Email": "kot@kot.com"}

# %%
student2
# Out:
# {'Name': 'Ala Kot', 'Age': 21, 'Email': 'kot@kot.com'}

# %%
studenci = [student, student2]

# %%
studenci
# Out:
# [{'Name': 'Patryk Hubar', 'Age': 31, 'Email': 'aaa@aaa.com'},
#  {'Name': 'Ala Kot', 'Age': 21, 'Email': 'kot@kot.com'}]

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("/content/programming_basics21112024.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.tail(25)
# Out:
#      PassengerId  Survived  Pclass  \
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Name"]

# %%
df[["Name", "Age"]]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
