# %%
import pandas as pd

# %%
MAIN_DATA = pd.read_csv("/content/programming_basics21112024(1).csv")

# %%
df_titanic = MAIN_DATA.copy()

# %%
df_titanic_roboczy = df_titanic.head().copy()

# %%
df_titanic

# %%
df_titanic.head()

# %%
df_titanic.tail()

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
type(df_titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df_titanic["Name"])
# Out:
# pandas.core.series.Series

# %%
df_titanic["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
lista = [1, 2, 3]

# %%
lista[0:3:2]
# Out:
# [1, 3]

# %%
lista.sort()

# %%
lista
# Out:
# [1, 2, 3]

# %%
values = [4, 5, 6]
indexes = ["a", "b", "c"]

# %%
seria = pd.Series(values, indexes)

# %%
seria
# Out:
# a    4
# b    5
# c    6
# dtype: int64

# %%
seria[0]
# Out:
# <ipython-input-26-1d74253bb11b>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   seria[0]
# 4

# %%
seria["a"]
# Out:
# 4

# %%
seria[0:3:2]
# Out:
# a    4
# c    6
# dtype: int64

# %%
seria.sort_values(ascending = False)
# Out:
# c    6
# b    5
# a    4
# dtype: int64

# %%
df = pd.DataFrame({"Kolumna1" : [1, 2, 3], "Kolumna2" : [4, 5, 6]})

# %%
df
# Out:
#    Kolumna1  Kolumna2
# a         1         4
# b         2         5
# c         3         6

# %%
#INDEKSOWANIE DF

#.iloc
#.loc

df.iloc[2, 1]
# Out:
# 6

# %%
df.iloc[0:3, 0:2]
# Out:
#    Kolumna1  Kolumna2
# 0         1         4
# 1         2         5
# 2         3         6

# %%
df.loc["a", "Kolumna1"]
# Out:
# 1

# %%
df

# %%
df["Kolumna3"] = ["Patryk", "Ola", "Ala"]

# %%
df
# Out:
#    Kolumna1  Kolumna2 Kolumna3
# 0         1         4   Patryk
# 1         2         5      Ola
# 2         3         6      Ala

# %%
del(df["Kolumna3"])

# %%
df
# Out:
#    Kolumna1  Kolumna2 Kolumna3
# 0         1         4   Patryk
# 1         2         5      Ola
# 2         3         6      Ala

# %%
df[df["Kolumna3"] == "Patryk"]
# Out:
#    Kolumna1  Kolumna2 Kolumna3
# 0         1         4   Patryk

# %%
lista
# Out:
# [1, 2, 3]

# %%
for elem in lista:
  print(elem)
# Out:
# 1
# 2
# 3

# %%
for elem in df:
  print(elem)
# Out:
# Kolumna1
# Kolumna2
# Kolumna3

# %%
for index, row in df.iterrows():
  print(index, row)

#ZLE

# %%
# LIST COMPREHENSION

lista
# Out:
# [1, 2, 3]

# %%
[elem for elem in lista]
# Out:
# [1, 2, 3]

# %%
[elem + 1 for elem in lista]
# Out:
# [2, 3, 4]

# %%
for elem in lista:
  print(elem + 1)
# Out:
# 2
# 3
# 4

# %%
df["Kolumna4"] = [elem.replace("a", "b") for elem in df["Kolumna3"]]

# %%
df
# Out:
#    Kolumna1  Kolumna2 Kolumna3 Kolumna4
# 0         1         4   Patryk   Pbtryk
# 1         2         5      Ola      Olb
# 2         3         6      Ala      Alb
